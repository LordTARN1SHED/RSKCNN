# %%
import tensorflow as tf
import os
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras import layers, Sequential, regularizers
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
import tensorflow.keras.preprocessing.image as image

# %%
np.set_printoptions(threshold=np.inf)#控制台输出所有的值，不需要省略号
#预处理
cifar10 = tf.keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

#数据集切分
x_valid,x_train=x_train[:3000],x_train[3000:]
y_valid,y_train=y_train[:3000],y_train[3000:]

# %%
#数据展示
labels = ['飞机','小汽车','鸟','猫','鹿','狗','青蛙','马','船','卡车']
plt.figure(figsize=(14,14)) 
#显示前10张图像，并在图像上显示类别
for i in range(20):   
    plt.subplot(4,5,i+1)
    plt.grid(False)
    plt.imshow(x_train[i,:,:,],cmap=plt.cm.binary)
    plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
    t = labels[y_train[i][0]]
    plt.title(t) 
plt.show()

# %%
class ResnetBlock(Model):

    def __init__(self, filters, strides=1, residual_path=False):
        super(ResnetBlock, self).__init__()
        self.filters = filters
        self.strides = strides
        self.residual_path = residual_path

        self.c1 = Conv2D(filters, (3, 3), strides=strides, padding='same',
                         kernel_regularizer=regularizers.l2(5e-5), use_bias=False, kernel_initializer='glorot_normal')
        self.b1 = BatchNormalization()
        self.a1 = Activation('relu')

        self.c2 = Conv2D(filters, (3, 3), strides=1, padding='same', 
                          kernel_regularizer=regularizers.l2(5e-5), use_bias=False, kernel_initializer='glorot_normal')
        self.b2 = BatchNormalization()

        # residual_path为True时，对输入进行下采样，即用1x1的卷积核做卷积操作，保证x能和F(x)维度相同，顺利相加
        if residual_path:
            self.down_c1 = Conv2D(filters, (1, 1), strides=strides, padding='same', 
                                  kernel_regularizer=regularizers.l2(5e-5), use_bias=False, kernel_initializer='glorot_normal')
            self.down_b1 = BatchNormalization()
        
        self.a2 = Activation('relu')

    def call(self, inputs):
        residual = inputs  # residual等于输入值本身，即residual=x
        # 将输入通过卷积、BN层、激活层，计算F(x)
        x = self.c1(inputs)
        x = self.b1(x)
        x = self.a1(x)

        x = self.c2(x)
        y = self.b2(x)

        if self.residual_path:
            residual = self.down_c1(inputs)
            residual = self.down_b1(residual)

        out = self.a2(y + residual)  # 最后输出的是两部分的和，即F(x)+x或F(x)+Wx,再过激活函数
        return out

# %%
class SparseConv2D(layers.Layer):
    def __init__(self, filters, kernel_size, p, **kwargs):
        super(SparseConv2D, self).__init__(**kwargs)
        self.filters = filters
        self.kernel_size = kernel_size
        self.p = tf.Variable(float(p), trainable=False)  # 将 p 转换为浮点数类型
        self.counter = tf.Variable(0, trainable=False, dtype=tf.int32)  # 初始化计数器

    def build(self, input_shape):
        self.kernel = self.add_weight(name='kernel',
                                      shape=(self.kernel_size, self.kernel_size, input_shape[-1], self.filters),
                                      initializer='glorot_uniform',
                                      trainable=True)
        self.bias = self.add_weight(name='bias',
                                    shape=(self.filters,),
                                    initializer='zeros',
                                    trainable=True)

    @tf.function
    def call(self, inputs, training=None):
        if training:
            mask = tf.random.uniform(shape=(self.filters,), minval=0, maxval=1)
            mask = tf.cast(mask < self.p, dtype=tf.float32)
            mask = tf.reshape(mask, [1, 1, 1, self.filters])
            #self.counter.assign_add(1)  # 更新计数器
            #tf.print("\nP is", self.p)  # 使用 tf.print
        else:
            mask = tf.ones([1, 1, 1, self.filters], dtype=tf.float32) * self.p
    
        sparse_kernel = self.kernel * mask
        conv = tf.nn.conv2d(inputs, sparse_kernel, strides=[1, 1, 1, 1], padding='SAME')
        return tf.nn.bias_add(conv, self.bias)

    @tf.function
    def update_p(self, new_p):
        self.p.assign(float(new_p))  # 使用 assign 更新 tf.Variable 的值，并转换为浮点数
        #tf.print("\nEpoch counter is", self.counter)  # 使用 tf.print
        #tf.print("\nP is", self.p)  # 使用 tf.print

# %%
class ResNet18(Model):

    def __init__(self, block_list, initial_filters=64):  # block_list表示每个block有几个卷积层
        super(ResNet18, self).__init__()
        self.num_blocks = len(block_list)  # 共有几个block
        self.block_list = block_list
        self.out_filters = initial_filters
        self.c1 = Conv2D(self.out_filters, (3, 3), strides=1, padding='same', use_bias=False)
        self.b1 = BatchNormalization()
        self.a1 = Activation('relu')
        self.blocks = tf.keras.models.Sequential()
        # 构建ResNet网络结构
        for block_id in range(len(block_list)):  # 第几个resnet block
            for layer_id in range(block_list[block_id]):  # 第几个卷积层

                if block_id != 0 and layer_id == 0:  # 对除第一个block以外的每个block的输入进行下采样
                    block = ResnetBlock(self.out_filters, strides=2, residual_path=True)
                else:
                    block = ResnetBlock(self.out_filters, residual_path=False)
                self.blocks.add(block)  # 将构建好的block加入resnet
            self.out_filters *= 2  # 下一个block的卷积核数是上一个block的2倍
        self.sparse_conv = SparseConv2D(filters=128, kernel_size=3, p=0.4, name='sparse_conv2d_3')
        self.p1 = tf.keras.layers.GlobalAveragePooling2D()
        self.f1 = tf.keras.layers.Dense(10, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2())#加softmax

    def call(self, inputs):
        x = self.c1(inputs)
        x = self.b1(x)
        x = self.a1(x)
        x = self.blocks(x)
        x = self.sparse_conv(x)  # 使用实例化的 SparseConv2D 层
        x = layers.Activation('relu')(x)
        x = self.p1(x)
        y = self.f1(x)
        return y

# %%
class UpdatePSparsity(tf.keras.callbacks.Callback):
    def __init__(self, model, sparsity_schedule):
        super(UpdatePSparsity, self).__init__()
        self.model = model
        self.sparsity_schedule = sparsity_schedule

    def on_epoch_end(self, epoch, logs=None):
        for layer_name, new_p in self.sparsity_schedule.items():
            layer = self.model.get_layer(name=layer_name)
            if epoch < len(new_p):
                p_value = new_p[epoch]
            else:
                p_value = new_p[-1]  # Use the last value for epochs beyond the predefined ones
            layer.update_p(p_value)

sparsity_schedule = {
    'sparse_conv2d_3': [0.4]
}

# %%
#模型训练
def model_train(x_train,y_train,x_valid,y_valid):
    
    model = ResNet18([2, 2, 2, 2])
    save_path = 'resnet18.h5'
    
    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
                  metrics=['sparse_categorical_accuracy'])
    
    checkpoint_save_path = "ResNet18.ckpt"
    if os.path.exists(checkpoint_save_path + '.index'):
        print('-------------load the model-----------------')
        model.load_weights(checkpoint_save_path)
    cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_save_path,
                                                 save_weights_only=True,
                                                 save_best_only=True)
    
    tensorboard = tf.keras.callbacks.TensorBoard(log_dir='./model',histogram_freq =1,write_grads=True)


    # 确保模型构建
    model.build(input_shape=(None, 32, 32, 3))
    model.summary()
    
    history = model.fit(x_train, y_train, batch_size=512, epochs=100, validation_data=(x_valid, y_valid), validation_freq=1,
                   callbacks=[tensorboard,UpdatePSparsity(model, sparsity_schedule)])
    #history = model.fit(x_train, y_train, batch_size=32, epochs=10, validation_data=(x_valid, y_valid), validation_freq=1,
                #   callbacks=[cp_callback])

    
    #权值保存
    file = open('./weights.txt', 'w')
    for v in model.trainable_variables:
        file.write(str(v.name) + '\n')
        file.write(str(v.shape) + '\n')
        file.write(str(v.numpy()) + '\n')
    file.close()
   
    #模型保存
    #model_path ='resnet18.h5'
    #tf.saved_model.save(model,model_path)
    #模型图保存
    #plot_model(model, to_file='resnet18_model.jpg',show_shapes=True)
    return history,model

# %%
#数据可视化
def figshow(history):
    '''
    introductoin:  数据可视化，画出训练损失函数和验证集上的准确率
    '''
    # 显示训练集和验证集的acc和loss曲线
    print('\n\n\n')
    print('----------------------------------------------图像绘制-------------------------------------')
    acc = history.history['sparse_categorical_accuracy']
    val_acc = history.history['val_sparse_categorical_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.subplots(figsize=(8,6))
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.show()

    plt.subplots(figsize=(8,6))
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.show()

# %%
#测试集测试
def data_test(x_test,y_test,model):
    '''
    @introduction :输出模型在测试集上的top1准确率和top2准确率
    @parameter ：
               x_test  测试集数据
               y_test  测试数据标签
               model   训练好的模型
    @return :
              top1_acc   top1标准下的准确率
              top2_acc   top2标准下的准确率
    
    '''
    print('****************************test******************************')
    loss, acc = model.evaluate(x_test, y_test)
    top1_acc = acc
    
    #print("test_accuracy:{:5.2f}%".format(100 * acc))
    y_pred = model.predict(x_test)
    k_b = tf.math.top_k(y_pred,2).indices
    idx=0
    acc=0.0
    for i in k_b:
        if y_test[idx] in i.numpy():
            acc=acc+1
        idx=idx+1
    top2_acc=acc/y_test.shape[0] 
    print('\n测试输出')
    print('top1准确率：{0}\ntop2准确率：{1}'.format(top1_acc,top2_acc))
    return top1_acc,top2_acc

# %%
if __name__ == '__main__':
    #训练
    history,model=model_train(x_train,y_train,x_test,y_test)
    figshow(history)
    
    
    #测试
    data_test(x_test,y_test,model)
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# Model: "res_net18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             multiple                  1728
#
#  batch_normalization (BatchN  multiple                 256
#  ormalization)
#
#  activation (Activation)     multiple                  0
#
#  sequential (Sequential)     (None, 4, 4, 512)         11176448
#
#  sparse_conv2d_3 (SparseConv  multiple                 589954
#  2D)
#
#  global_average_pooling2d (G  multiple                 0
#  lobalAveragePooling2D)
#
#  dense (Dense)               multiple                  1290
#
# =================================================================
# Total params: 11,769,676
# Trainable params: 11,760,074
# Non-trainable params: 9,602
# _________________________________________________________________
# Epoch 1/100
#  6/92 [>.............................] - ETA: 9s - loss: 3.1921 - sparse_categorical_accuracy: 0.1214WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0415s vs `on_train_batch_end` time: 0.0667s). Check your callbacks.
# 92/92 [==============================] - 19s 148ms/step - loss: 2.6454 - sparse_categorical_accuracy: 0.1723 - val_loss: 2.6829 - val_sparse_categorical_accuracy: 0.1278
# Epoch 2/100
# 92/92 [==============================] - 12s 129ms/step - loss: 2.1159 - sparse_categorical_accuracy: 0.3125 - val_loss: 3.0448 - val_sparse_categorical_accuracy: 0.1002
# Epoch 3/100
# 92/92 [==============================] - 12s 129ms/step - loss: 1.8202 - sparse_categorical_accuracy: 0.4299 - val_loss: 3.5326 - val_sparse_categorical_accuracy: 0.1067
# Epoch 4/100
# 92/92 [==============================] - 12s 129ms/step - loss: 1.5719 - sparse_categorical_accuracy: 0.5222 - val_loss: 2.3943 - val_sparse_categorical_accuracy: 0.3175
# Epoch 5/100
# 92/92 [==============================] - 12s 130ms/step - loss: 1.3896 - sparse_categorical_accuracy: 0.5936 - val_loss: 1.8427 - val_sparse_categorical_accuracy: 0.4514
# Epoch 6/100
# 92/92 [==============================] - 12s 130ms/step - loss: 1.2529 - sparse_categorical_accuracy: 0.6360 - val_loss: 1.4978 - val_sparse_categorical_accuracy: 0.5542
# Epoch 7/100
# 92/92 [==============================] - 12s 129ms/step - loss: 1.1205 - sparse_categorical_accuracy: 0.6851 - val_loss: 2.3495 - val_sparse_categorical_accuracy: 0.4355
# Epoch 8/100
# 92/92 [==============================] - 12s 129ms/step - loss: 1.0325 - sparse_categorical_accuracy: 0.7222 - val_loss: 1.2238 - val_sparse_categorical_accuracy: 0.6681
# Epoch 9/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.9512 - sparse_categorical_accuracy: 0.7528 - val_loss: 1.3393 - val_sparse_categorical_accuracy: 0.6098
# Epoch 10/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.8697 - sparse_categorical_accuracy: 0.7850 - val_loss: 1.1814 - val_sparse_categorical_accuracy: 0.6930
# Epoch 11/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.7918 - sparse_categorical_accuracy: 0.8138 - val_loss: 1.0971 - val_sparse_categorical_accuracy: 0.7189
# Epoch 12/100
# 92/92 [==============================] - 12s 131ms/step - loss: 0.7340 - sparse_categorical_accuracy: 0.8330 - val_loss: 1.1168 - val_sparse_categorical_accuracy: 0.7200
# Epoch 13/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.6779 - sparse_categorical_accuracy: 0.8538 - val_loss: 1.2207 - val_sparse_categorical_accuracy: 0.7179
# Epoch 14/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.6288 - sparse_categorical_accuracy: 0.8715 - val_loss: 1.2168 - val_sparse_categorical_accuracy: 0.7144
# Epoch 15/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.6208 - sparse_categorical_accuracy: 0.8786 - val_loss: 1.4185 - val_sparse_categorical_accuracy: 0.6832
# Epoch 16/100
# 92/92 [==============================] - 12s 131ms/step - loss: 0.5378 - sparse_categorical_accuracy: 0.9066 - val_loss: 1.1315 - val_sparse_categorical_accuracy: 0.7551
# Epoch 17/100
# 92/92 [==============================] - 12s 131ms/step - loss: 0.5162 - sparse_categorical_accuracy: 0.9148 - val_loss: 2.2116 - val_sparse_categorical_accuracy: 0.5975
# Epoch 18/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.5194 - sparse_categorical_accuracy: 0.9155 - val_loss: 1.2240 - val_sparse_categorical_accuracy: 0.7439
# Epoch 19/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.4939 - sparse_categorical_accuracy: 0.9186 - val_loss: 1.8517 - val_sparse_categorical_accuracy: 0.6843
# Epoch 20/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.4649 - sparse_categorical_accuracy: 0.9353 - val_loss: 1.1516 - val_sparse_categorical_accuracy: 0.7820
# Epoch 21/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.4281 - sparse_categorical_accuracy: 0.9465 - val_loss: 1.3117 - val_sparse_categorical_accuracy: 0.7793
# Epoch 22/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.4326 - sparse_categorical_accuracy: 0.9485 - val_loss: 1.2189 - val_sparse_categorical_accuracy: 0.7907
# Epoch 23/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.4007 - sparse_categorical_accuracy: 0.9619 - val_loss: 1.8743 - val_sparse_categorical_accuracy: 0.7103
# Epoch 24/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.4345 - sparse_categorical_accuracy: 0.9485 - val_loss: 1.3440 - val_sparse_categorical_accuracy: 0.7624
# Epoch 25/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.4021 - sparse_categorical_accuracy: 0.9611 - val_loss: 1.2588 - val_sparse_categorical_accuracy: 0.7855
# Epoch 26/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3773 - sparse_categorical_accuracy: 0.9674 - val_loss: 1.4214 - val_sparse_categorical_accuracy: 0.7705
# Epoch 27/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.4131 - sparse_categorical_accuracy: 0.9554 - val_loss: 1.4744 - val_sparse_categorical_accuracy: 0.7685
# Epoch 28/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.4035 - sparse_categorical_accuracy: 0.9605 - val_loss: 1.3132 - val_sparse_categorical_accuracy: 0.7912
# Epoch 29/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.4054 - sparse_categorical_accuracy: 0.9590 - val_loss: 1.6115 - val_sparse_categorical_accuracy: 0.7502
# Epoch 30/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3769 - sparse_categorical_accuracy: 0.9693 - val_loss: 1.1701 - val_sparse_categorical_accuracy: 0.8172
# Epoch 31/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3584 - sparse_categorical_accuracy: 0.9754 - val_loss: 1.8562 - val_sparse_categorical_accuracy: 0.7445
# Epoch 32/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3816 - sparse_categorical_accuracy: 0.9664 - val_loss: 1.6577 - val_sparse_categorical_accuracy: 0.7576
# Epoch 33/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3869 - sparse_categorical_accuracy: 0.9619 - val_loss: 1.6226 - val_sparse_categorical_accuracy: 0.7678
# Epoch 34/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3773 - sparse_categorical_accuracy: 0.9711 - val_loss: 1.5694 - val_sparse_categorical_accuracy: 0.7772
# Epoch 35/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3521 - sparse_categorical_accuracy: 0.9770 - val_loss: 1.4351 - val_sparse_categorical_accuracy: 0.7836
# Epoch 36/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3633 - sparse_categorical_accuracy: 0.9746 - val_loss: 1.5542 - val_sparse_categorical_accuracy: 0.7831
# Epoch 37/100
# 92/92 [==============================] - 12s 128ms/step - loss: 0.3733 - sparse_categorical_accuracy: 0.9696 - val_loss: 2.0939 - val_sparse_categorical_accuracy: 0.7372
# Epoch 38/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3841 - sparse_categorical_accuracy: 0.9696 - val_loss: 1.5127 - val_sparse_categorical_accuracy: 0.7880
# Epoch 39/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3686 - sparse_categorical_accuracy: 0.9714 - val_loss: 1.4076 - val_sparse_categorical_accuracy: 0.8069
# Epoch 40/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3624 - sparse_categorical_accuracy: 0.9716 - val_loss: 1.7153 - val_sparse_categorical_accuracy: 0.7461
# Epoch 41/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3795 - sparse_categorical_accuracy: 0.9693 - val_loss: 1.4789 - val_sparse_categorical_accuracy: 0.7925
# Epoch 42/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3630 - sparse_categorical_accuracy: 0.9711 - val_loss: 1.4905 - val_sparse_categorical_accuracy: 0.7898
# Epoch 43/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3756 - sparse_categorical_accuracy: 0.9699 - val_loss: 1.6420 - val_sparse_categorical_accuracy: 0.7672
# Epoch 44/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3719 - sparse_categorical_accuracy: 0.9733 - val_loss: 1.4854 - val_sparse_categorical_accuracy: 0.7943
# Epoch 45/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3668 - sparse_categorical_accuracy: 0.9697 - val_loss: 1.4213 - val_sparse_categorical_accuracy: 0.7898
# Epoch 46/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3671 - sparse_categorical_accuracy: 0.9707 - val_loss: 1.8982 - val_sparse_categorical_accuracy: 0.7468
# Epoch 47/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3699 - sparse_categorical_accuracy: 0.9730 - val_loss: 1.4847 - val_sparse_categorical_accuracy: 0.7992
# Epoch 48/100
# 92/92 [==============================] - 12s 128ms/step - loss: 0.3510 - sparse_categorical_accuracy: 0.9806 - val_loss: 1.6819 - val_sparse_categorical_accuracy: 0.7800
# Epoch 49/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3436 - sparse_categorical_accuracy: 0.9800 - val_loss: 1.5703 - val_sparse_categorical_accuracy: 0.7769
# Epoch 50/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3559 - sparse_categorical_accuracy: 0.9755 - val_loss: 1.6430 - val_sparse_categorical_accuracy: 0.7852
# Epoch 51/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3562 - sparse_categorical_accuracy: 0.9746 - val_loss: 1.4792 - val_sparse_categorical_accuracy: 0.7926
# Epoch 52/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3665 - sparse_categorical_accuracy: 0.9724 - val_loss: 1.6850 - val_sparse_categorical_accuracy: 0.7838
# Epoch 53/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3592 - sparse_categorical_accuracy: 0.9754 - val_loss: 1.6770 - val_sparse_categorical_accuracy: 0.7943
# Epoch 54/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3571 - sparse_categorical_accuracy: 0.9782 - val_loss: 2.3725 - val_sparse_categorical_accuracy: 0.7358
# Epoch 55/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3639 - sparse_categorical_accuracy: 0.9767 - val_loss: 1.4221 - val_sparse_categorical_accuracy: 0.8063
# Epoch 56/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3394 - sparse_categorical_accuracy: 0.9816 - val_loss: 1.5093 - val_sparse_categorical_accuracy: 0.8030
# Epoch 57/100
# 92/92 [==============================] - 12s 128ms/step - loss: 0.3632 - sparse_categorical_accuracy: 0.9719 - val_loss: 1.6249 - val_sparse_categorical_accuracy: 0.7890
# Epoch 58/100
# 92/92 [==============================] - 12s 127ms/step - loss: 0.3338 - sparse_categorical_accuracy: 0.9813 - val_loss: 1.5249 - val_sparse_categorical_accuracy: 0.8026
# Epoch 59/100
# 92/92 [==============================] - 12s 127ms/step - loss: 0.3476 - sparse_categorical_accuracy: 0.9782 - val_loss: 1.8357 - val_sparse_categorical_accuracy: 0.7620
# Epoch 60/100
# 92/92 [==============================] - 12s 128ms/step - loss: 0.3638 - sparse_categorical_accuracy: 0.9733 - val_loss: 1.7827 - val_sparse_categorical_accuracy: 0.7624
# Epoch 61/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3628 - sparse_categorical_accuracy: 0.9771 - val_loss: 1.6326 - val_sparse_categorical_accuracy: 0.8036
# Epoch 62/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3317 - sparse_categorical_accuracy: 0.9851 - val_loss: 1.5671 - val_sparse_categorical_accuracy: 0.7930
# Epoch 63/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3498 - sparse_categorical_accuracy: 0.9763 - val_loss: 1.4987 - val_sparse_categorical_accuracy: 0.7869
# Epoch 64/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3142 - sparse_categorical_accuracy: 0.9885 - val_loss: 1.7664 - val_sparse_categorical_accuracy: 0.7730
# Epoch 65/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3340 - sparse_categorical_accuracy: 0.9790 - val_loss: 1.5224 - val_sparse_categorical_accuracy: 0.8015
# Epoch 66/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3477 - sparse_categorical_accuracy: 0.9780 - val_loss: 1.7936 - val_sparse_categorical_accuracy: 0.7750
# Epoch 67/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3390 - sparse_categorical_accuracy: 0.9826 - val_loss: 1.6210 - val_sparse_categorical_accuracy: 0.7781
# Epoch 68/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3443 - sparse_categorical_accuracy: 0.9764 - val_loss: 1.4512 - val_sparse_categorical_accuracy: 0.8083
# Epoch 69/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3517 - sparse_categorical_accuracy: 0.9775 - val_loss: 1.4068 - val_sparse_categorical_accuracy: 0.8047
# Epoch 70/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3484 - sparse_categorical_accuracy: 0.9821 - val_loss: 1.9514 - val_sparse_categorical_accuracy: 0.7501
# Epoch 71/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3233 - sparse_categorical_accuracy: 0.9858 - val_loss: 1.4754 - val_sparse_categorical_accuracy: 0.7938
# Epoch 72/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3291 - sparse_categorical_accuracy: 0.9828 - val_loss: 1.5399 - val_sparse_categorical_accuracy: 0.8098
# Epoch 73/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3275 - sparse_categorical_accuracy: 0.9803 - val_loss: 1.6115 - val_sparse_categorical_accuracy: 0.7900
# Epoch 74/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3291 - sparse_categorical_accuracy: 0.9842 - val_loss: 1.5289 - val_sparse_categorical_accuracy: 0.7955
# Epoch 75/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3215 - sparse_categorical_accuracy: 0.9828 - val_loss: 1.8337 - val_sparse_categorical_accuracy: 0.7756
# Epoch 76/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3311 - sparse_categorical_accuracy: 0.9844 - val_loss: 1.7351 - val_sparse_categorical_accuracy: 0.7680
# Epoch 77/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3262 - sparse_categorical_accuracy: 0.9860 - val_loss: 1.6567 - val_sparse_categorical_accuracy: 0.7800
# Epoch 78/100
# 92/92 [==============================] - 12s 128ms/step - loss: 0.3299 - sparse_categorical_accuracy: 0.9835 - val_loss: 1.5709 - val_sparse_categorical_accuracy: 0.8047
# Epoch 79/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3279 - sparse_categorical_accuracy: 0.9797 - val_loss: 1.5784 - val_sparse_categorical_accuracy: 0.7996
# Epoch 80/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3269 - sparse_categorical_accuracy: 0.9811 - val_loss: 1.4494 - val_sparse_categorical_accuracy: 0.8124
# Epoch 81/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3332 - sparse_categorical_accuracy: 0.9776 - val_loss: 1.6154 - val_sparse_categorical_accuracy: 0.7821
# Epoch 82/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3168 - sparse_categorical_accuracy: 0.9868 - val_loss: 1.7359 - val_sparse_categorical_accuracy: 0.7706
# Epoch 83/100
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3254 - sparse_categorical_accuracy: 0.9821 - val_loss: 1.6040 - val_sparse_categorical_accuracy: 0.7901
# Epoch 84/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3180 - sparse_categorical_accuracy: 0.9844 - val_loss: 1.8190 - val_sparse_categorical_accuracy: 0.7745
# Epoch 85/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3250 - sparse_categorical_accuracy: 0.9823 - val_loss: 2.4537 - val_sparse_categorical_accuracy: 0.7219
# Epoch 86/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3374 - sparse_categorical_accuracy: 0.9808 - val_loss: 2.3257 - val_sparse_categorical_accuracy: 0.6945
# Epoch 87/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3207 - sparse_categorical_accuracy: 0.9866 - val_loss: 2.0741 - val_sparse_categorical_accuracy: 0.7826
# Epoch 88/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3036 - sparse_categorical_accuracy: 0.9864 - val_loss: 1.6730 - val_sparse_categorical_accuracy: 0.8000
# Epoch 89/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3246 - sparse_categorical_accuracy: 0.9777 - val_loss: 1.8118 - val_sparse_categorical_accuracy: 0.7918
# Epoch 90/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3394 - sparse_categorical_accuracy: 0.9781 - val_loss: 1.7299 - val_sparse_categorical_accuracy: 0.7861
# Epoch 91/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3366 - sparse_categorical_accuracy: 0.9808 - val_loss: 1.6501 - val_sparse_categorical_accuracy: 0.8121
# Epoch 92/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3462 - sparse_categorical_accuracy: 0.9756 - val_loss: 1.7651 - val_sparse_categorical_accuracy: 0.7758
# Epoch 93/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3415 - sparse_categorical_accuracy: 0.9778 - val_loss: 1.9828 - val_sparse_categorical_accuracy: 0.7593
# Epoch 94/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3193 - sparse_categorical_accuracy: 0.9867 - val_loss: 1.8995 - val_sparse_categorical_accuracy: 0.7717
# Epoch 95/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3163 - sparse_categorical_accuracy: 0.9822 - val_loss: 1.5543 - val_sparse_categorical_accuracy: 0.7955
# Epoch 96/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3222 - sparse_categorical_accuracy: 0.9846 - val_loss: 1.9321 - val_sparse_categorical_accuracy: 0.7683
# Epoch 97/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3194 - sparse_categorical_accuracy: 0.9846 - val_loss: 2.0221 - val_sparse_categorical_accuracy: 0.7623
# Epoch 98/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3258 - sparse_categorical_accuracy: 0.9801 - val_loss: 1.9495 - val_sparse_categorical_accuracy: 0.7653
# Epoch 99/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3294 - sparse_categorical_accuracy: 0.9835 - val_loss: 1.5108 - val_sparse_categorical_accuracy: 0.8035
# Epoch 100/100
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3134 - sparse_categorical_accuracy: 0.9831 - val_loss: 1.4747 - val_sparse_categorical_accuracy: 0.8155
#
#
#
#
# ----------------------------------------------图像绘制-------------------------------------
# ****************************test******************************
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4747 - sparse_categorical_accuracy: 0.8156
# 313/313 [==============================] - 2s 5ms/step
#
# 测试输出
# top1准确率：0.8155999779701233
# top2准确率：0.9146
